# %%
import pandas as pd
import numpy as np

# %%
county_mobility = pd.read_csv("County_Mobility_Report.csv")

# %%
Suffix_List = ["County"]
county_mobility["COUNTY"] = county_mobility["sub_region_2"].str.replace("\s?(" + "|".join(Suffix_List) + ")$", "")
county_mobility.head()
# Out:
#   country_region_code country_region    STATE    sub_region_2     date  \
# 0                  US  United States  Alabama  Autauga County  2/15/20
# 1                  US  United States  Alabama  Autauga County  2/16/20
# 2                  US  United States  Alabama  Autauga County  2/17/20
# 3                  US  United States  Alabama  Autauga County  2/18/20
# 4                  US  United States  Alabama  Autauga County  2/19/20
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                5.0
# 1                                                0.0
# 2                                                8.0
# 3                                               -2.0
# 4                                               -2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                7.0
# 1                                                1.0
# ...

# %%
combined_data = pd.read_csv("combined_csv.csv")
combined_data.head()
# Out:
#      date  Source   Site ID  POC  Daily Mean PM2.5 Concentration     UNITS  \
# 0  2/8/20  AirNow  10730023    3                             6.7  ug/m3 LC
# 1  2/8/20  AirNow  10731005    3                             6.0  ug/m3 LC
# 2  2/8/20  AirNow  10732003    3                             7.9  ug/m3 LC
# 3  2/8/20  AirNow  10735003    3                             5.8  ug/m3 LC
# 4  2/8/20  AirNow  10736004    3                            11.0  ug/m3 LC
#
#    DAILY_AQI_VALUE            Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0               28     North Birmingham                1               100
# 1               25              McAdory                1               100
# 2               33                Wylam                1               100
# 3               24               Corner                1               100
# 4               46  Sloss Shuttlesworth                1               100
#
# ...

# %%
#all_data = pd.merge(combined_data, county_mobility, how='outer', left_on=["STATE","COUNTY","date"], right_on=["STATE","COUNTY","date"])
all_data = combined_data.merge(county_mobility, how='outer', left_on=["STATE","COUNTY","date"], right_on=["STATE","COUNTY","date"])
#merged_df = left_df.merge(right_df, how='inner', left_on=["A", "B"], right_on=["A2","B2"])
all_data.head(100)
# Out:
#        date  Source     Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0    2/8/20  AirNow  10730023.0  3.0                             6.7
# 1    2/8/20  AirNow  10731005.0  3.0                             6.0
# 2    2/8/20  AirNow  10732003.0  3.0                             7.9
# 3    2/8/20  AirNow  10735003.0  3.0                             5.8
# 4    2/8/20  AirNow  10736004.0  3.0                            11.0
# ..      ...     ...         ...  ...                             ...
# 95  2/27/20  AirNow  10736004.0  3.0                             9.0
# 96  2/28/20  AirNow  10730023.0  3.0                             6.7
# 97  2/28/20  AirNow  10731005.0  3.0                             5.7
# 98  2/28/20  AirNow  10732003.0  3.0                             4.0
# 99  2/28/20  AirNow  10735003.0  3.0                             3.5
#
#        UNITS  DAILY_AQI_VALUE            Site Name  DAILY_OBS_COUNT  \
# 0   ug/m3 LC             28.0     North Birmingham              1.0
# ...

# %%
all_data.tail()
# Out:
#            date Source  Site ID  POC  Daily Mean PM2.5 Concentration UNITS  \
# 187281   4/6/20    NaN      NaN  NaN                             NaN   NaN
# 187282   4/7/20    NaN      NaN  NaN                             NaN   NaN
# 187283   4/8/20    NaN      NaN  NaN                             NaN   NaN
# 187284   4/9/20    NaN      NaN  NaN                             NaN   NaN
# 187285  4/10/20    NaN      NaN  NaN                             NaN   NaN
#
#         DAILY_AQI_VALUE Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  ...  \
# 187281              NaN       NaN              NaN               NaN  ...
# 187282              NaN       NaN              NaN               NaN  ...
# 187283              NaN       NaN              NaN               NaN  ...
# 187284              NaN       NaN              NaN               NaN  ...
# 187285              NaN       NaN              NaN               NaN  ...
#
# ...

# %%
air_movement = all_data[pd.notnull(all_data['residential_percent_change_from_baseline'])]
air_movement.head()
# Out:
#        date  Source     Site ID  POC  Daily Mean PM2.5 Concentration  \
# 35  2/15/20  AirNow  10730023.0  3.0                             8.1
# 36  2/15/20  AirNow  10731005.0  3.0                             6.7
# 37  2/15/20  AirNow  10732003.0  3.0                             9.6
# 38  2/15/20  AirNow  10735003.0  3.0                             5.4
# 39  2/15/20  AirNow  10736004.0  3.0                             7.4
#
#        UNITS  DAILY_AQI_VALUE            Site Name  DAILY_OBS_COUNT  \
# 35  ug/m3 LC             34.0     North Birmingham              1.0
# 36  ug/m3 LC             28.0              McAdory              1.0
# 37  ug/m3 LC             40.0                Wylam              1.0
# 38  ug/m3 LC             23.0               Corner              1.0
# 39  ug/m3 LC             31.0  Sloss Shuttlesworth              1.0
#
#     PERCENT_COMPLETE  ...  SITE_LONGITUDE country_region_code  country_region  \
# ...

# %%
air_movement.to_csv("air_movement_changes");

# %%
#frames = [combined_data, county_mobility]

#result = pd.concat(frames)

#result = pd.concat([combined_data, county_mobility], ignore_index=True, sort=False)
result = county_mobility.append(combined_data, ignore_index=True, sort=False)
result.dropna(subset=['DAILY_AQI_VALUE'])
result.head()
# Out:
#     country_region_code country_region sub_region_1    sub_region_2     date  \
# 0                    US  United States      Alabama  Autauga County  2/15/20
# 1                    US  United States      Alabama  Autauga County  2/16/20
# 2                    US  United States      Alabama  Autauga County  2/17/20
# 3                    US  United States      Alabama  Autauga County  2/18/20
# 4                    US  United States      Alabama  Autauga County  2/19/20
# ..                  ...            ...          ...             ...      ...
# 995                  US  United States      Alabama  Conecuh County  3/15/20
# 996                  US  United States      Alabama  Conecuh County  3/16/20
# 997                  US  United States      Alabama  Conecuh County  3/17/20
# 998                  US  United States      Alabama  Conecuh County  3/18/20
# 999                  US  United States      Alabama  Conecuh County  3/19/20
#
# ...

# %%
result = county_mobility.append(combined_data, sort=False)
result.head()
# Out:
#   country_region_code country_region sub_region_1    sub_region_2     date  \
# 0                  US  United States      Alabama  Autauga County  2/15/20
# 1                  US  United States      Alabama  Autauga County  2/16/20
# 2                  US  United States      Alabama  Autauga County  2/17/20
# 3                  US  United States      Alabama  Autauga County  2/18/20
# 4                  US  United States      Alabama  Autauga County  2/19/20
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                5.0
# 1                                                0.0
# 2                                                8.0
# 3                                               -2.0
# 4                                               -2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                7.0
# 1                                                1.0
# ...

# %%
#result[result['DAILY_AQI_VALUE'].notna()]
#result.dropna(subset=['DAILY_AQI_VALUE'])
# Out:
#       country_region_code country_region sub_region_1 sub_region_2 date  \
# 0                     NaN            NaN          NaN          NaN  NaN
# 1                     NaN            NaN          NaN          NaN  NaN
# 2                     NaN            NaN          NaN          NaN  NaN
# 3                     NaN            NaN          NaN          NaN  NaN
# 4                     NaN            NaN          NaN          NaN  NaN
# ...                   ...            ...          ...          ...  ...
# 99919                 NaN            NaN          NaN          NaN  NaN
# 99920                 NaN            NaN          NaN          NaN  NaN
# 99921                 NaN            NaN          NaN          NaN  NaN
# 99922                 NaN            NaN          NaN          NaN  NaN
# 99923                 NaN            NaN          NaN          NaN  NaN
#
#        retail_and_recreation_percent_change_from_baseline  \
# ...

# %%
def get_AQI_Value(STATE, COUNTY, Date):
    try:
        return combined_data.loc[STATE][COUNTY][Date]
    except:
        return np.NaN

# %%
# Out:
# nan

# %%
#grouped = pd.DataFrame(combined_data.groupby(['STATE','COUNTY', 'Date']).mean()['DAILY_AQI_VALUE'])
#grouped.head()
# Out:
#                            DAILY_AQI_VALUE
# STATE   COUNTY    Date
# Alabama Jefferson 1/1/20         30.833333
#                   1/10/20        39.000000
#                   1/11/20        26.666667
#                   1/12/20        27.166667
#                   1/13/20        35.333333
